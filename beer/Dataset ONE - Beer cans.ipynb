# %% [markdown]
# # Homework 6, Part One: Lots and lots of questions about beer

# %% [markdown]
# ### Do your importing and your setup

# %%
import pandas as pd
import numpy as np

# %matplotlib inline

# %% [markdown]
# ## Read in the file `craftcans.csv`, and look at the first first rows

# %%
df = pd.read_csv("craftcans.csv", na_values=['Does not apply'])
df.head(5)
#na_values=[0, "UNKNOWN"]
#df = pd.read_csv("neiss2017.tsv", sep='\t', encoding='latin-1', na_values=[0, "UNKNOWN"])
# Out:
#             Beer            Brewery         Location               Style  \
# 0   Get Together  NorthGate Brewing  Minneapolis, MN        American IPA
# 1  Maggie's Leap  NorthGate Brewing  Minneapolis, MN  Milk / Sweet Stout
# 2     Wall's End  NorthGate Brewing  Minneapolis, MN   English Brown Ale
# 3        Pumpion  NorthGate Brewing  Minneapolis, MN         Pumpkin Ale
# 4     Stronghold  NorthGate Brewing  Minneapolis, MN     American Porter
#
#      Size    ABV  IBUs
# 0  16 oz.  4.50%  50.0
# 1  16 oz.  4.90%  26.0
# 2  16 oz.  4.80%  19.0
# 3  16 oz.  6.00%  38.0
# 4  16 oz.  6.00%  25.0

# %% [markdown]
# ## How many rows do you have in the data? What are the column types?

# %%
df.shape
# Out:
# (2416, 7)

# %%
df.dtypes
# Out:
# Beer         object
# Brewery      object
# Location     object
# Style        object
# Size         object
# ABV          object
# IBUs        float64
# dtype: object

# %% [markdown]
# # Checking out our alcohol

# %% [markdown]
# ## What are the top 10 producers of cans of beer?

# %%
df.Brewery.value_counts().head(10)
# Out:
# Brewery Vivant                62
# Oskar Blues Brewery           46
# Sun King Brewing Company      38
# Cigar City Brewing Company    25
# Sixpoint Craft Ales           24
# Hopworks Urban Brewery        23
# Stevens Point Brewery         22
# 21st Amendment Brewery        20
# Great Crescent Brewery        20
# SanTan Brewing Company        19
# Name: Brewery, dtype: int64

# %% [markdown]
# ## What is the most common ABV? (alcohol by volume)

# %%
df.ABV.value_counts().head()
# Out:
# 5.00%    215
# 5.50%    158
# 6.00%    125
# 6.50%    123
# 5.20%    107
# Name: ABV, dtype: int64

# %% [markdown]
# ## Oh, weird, ABV isn't a number. Convert it to a number for me, please.
#
# It's going to take a few steps!
#
# ### First, let's just look at the ABV column by itself

# %%
df.ABV
# Out:
# 0        4.50%
# 1        4.90%
# 2        4.80%
# 3        6.00%
# 4        6.00%
# 5        5.60%
# 6        8.00%
# 7       12.50%
# 8        7.70%
# 9        4.20%
# 10       5.00%
# 11       6.60%
# 12       4.00%
# 13       5.50%
# 14       7.60%
# 15       5.10%
# 16       6.50%
# 17       6.00%
# 18       5.00%
# 19       5.20%
# 20       4.80%
# 21       7.20%
# 22       6.70%
# 23       4.90%
# 24       8.00%
# 25       7.50%
# 26       6.00%
# 27       8.00%
# 28       6.30%
# 29       5.80%
#          ...
# 2386     5.70%
# 2387     6.20%
# 2388     4.90%
# 2389     9.90%
# 2390     6.20%
# 2391     5.80%
# 2392     5.20%
# 2393     8.50%
# 2394     7.00%
# 2395     5.30%
# 2396     5.60%
# 2397     4.90%
# 2398     5.10%
# 2399     4.00%
# 2400     5.50%
# 2401     5.10%
# 2402     5.10%
# 2403     9.70%
# 2404     5.10%
# 2405     6.70%
# 2406     6.20%
# 2407     8.30%
# 2408     7.00%
# 2409     4.90%
# 2410     9.90%
# 2411     5.30%
# 2412     9.90%
# 2413     8.00%
# 2414     8.70%
# 2415     6.50%
# Name: ABV, Length: 2416, dtype: object

# %% [markdown]
# ### Hm, `%` isn't part of  a number. Let's remove it.
#
# When you're confident you got it right, save the results back into the `ABV` column.
#
# - *Tip: In programming the easiest way to remove something is to *replacing it with nothing*.
# - *Tip: "nothing" might seem like `NaN` sinc we talked about it a lot in class, but in this case it isn't! It's just an empty string, like ""*
# - *Tip: `.replace` is used for replacing ENTIRE cells, while `.str.replace` is useful for replacing PARTS of cells (see my New York example)*

# %%
df['ABV'] = df.ABV.str.replace('%', '')

# %% [markdown]
# ### Now let's turn `ABV` into a numeric data type
#
# Save the results back into the `ABV` column (again), and then check `df.dtypes` to make sure it worked.
#
# - *Tip: We used `.astype(int)` during class, but this has a decimal in it...*

# %%
df['ABV'] = df.ABV.astype(float)
df.ABV
# Out:
# 0        4.5
# 1        4.9
# 2        4.8
# 3        6.0
# 4        6.0
# 5        5.6
# 6        8.0
# 7       12.5
# 8        7.7
# 9        4.2
# 10       5.0
# 11       6.6
# 12       4.0
# 13       5.5
# 14       7.6
# 15       5.1
# 16       6.5
# 17       6.0
# 18       5.0
# 19       5.2
# 20       4.8
# 21       7.2
# 22       6.7
# 23       4.9
# 24       8.0
# 25       7.5
# 26       6.0
# 27       8.0
# 28       6.3
# 29       5.8
#         ...
# 2386     5.7
# 2387     6.2
# 2388     4.9
# 2389     9.9
# 2390     6.2
# 2391     5.8
# 2392     5.2
# 2393     8.5
# 2394     7.0
# 2395     5.3
# 2396     5.6
# 2397     4.9
# 2398     5.1
# 2399     4.0
# 2400     5.5
# 2401     5.1
# 2402     5.1
# 2403     9.7
# 2404     5.1
# 2405     6.7
# 2406     6.2
# 2407     8.3
# 2408     7.0
# 2409     4.9
# 2410     9.9
# 2411     5.3
# 2412     9.9
# 2413     8.0
# 2414     8.7
# 2415     6.5
# Name: ABV, Length: 2416, dtype: float64

# %% [markdown]
# ## What's the ABV of the average beer look like?
#
# ### Show me in two different ways: one command to show the `median`/`mean`/etc, and secondly show me a chart

# %%
df.ABV.describe()
# Out:
# count    2348.000000
# mean        5.977342
# std         1.354173
# min         0.100000
# 25%         5.000000
# 50%         5.600000
# 75%         6.700000
# max        12.800000
# Name: ABV, dtype: float64

# %%
df.ABV.hist(bins = 50)

# %% [markdown]
# ### We don't have ABV for all of the beers, how many are we missing them from?
#
# - *Tip: You can use `isnull()` or `notnull()` to see where a column is missing data.*
# - *Tip: You just want to count how many `True`s and `False`s there are.*
# - *Tip: It's a weird trick involving something we usually use to count things in a column*

# %%
df.ABV.isna()
df.ABV.isna().sum()
# Out:
# 68

# %% [markdown]
# # Looking at location
#
# Brooklyn used to produce 80% of the country's beer! Let's see if it's still true.

# %% [markdown]
# ## What are the top 10 cities in the US for canned craft beer?

# %%
df
# Out:
#                                        Beer                        Brewery  \
# 0                              Get Together              NorthGate Brewing
# 1                             Maggie's Leap              NorthGate Brewing
# 2                                Wall's End              NorthGate Brewing
# 3                                   Pumpion              NorthGate Brewing
# 4                                Stronghold              NorthGate Brewing
# 5                               Parapet ESB              NorthGate Brewing
# 6                            Citra Ass Down      Against the Grain Brewery
# 7                            London Balling      Against the Grain Brewery
# 8                                      35 K      Against the Grain Brewery
# 9                                    A Beer      Against the Grain Brewery
# 10                          Rules are Rules      Against the Grain Brewery
# 11                            Flesh Gourd'n      Against the Grain Brewery
# 12                                 Sho'nuff      Against the Grain Brewery
# 13                              Bloody Show      Against the Grain Brewery
# 14                              Rico Sauvin      Against the Grain Brewery
# 15                         Coq de la Marche      Against the Grain Brewery
# 16                           Kamen Knuddeln      Against the Grain Brewery
# 17                             Pile of Face      Against the Grain Brewery
# 18                           The Brown Note      Against the Grain Brewery
# 19                              House Lager       Jack's Abby Craft Lagers
# 20                             Leisure Time       Jack's Abby Craft Lagers
# 21                               Excess IPL       Jack's Abby Craft Lagers
# 22                           Hoponius Union       Jack's Abby Craft Lagers
# 23                                 Calyptra       Jack's Abby Craft Lagers
# 24                           Habitus (2014)      Mike Hess Brewing Company
# 25                                    Solis      Mike Hess Brewing Company
# 26                                 Jucundus      Mike Hess Brewing Company
# 27                                  Habitus      Mike Hess Brewing Company
# 28                                  Grazias      Mike Hess Brewing Company
# 29                                 Claritas      Mike Hess Brewing Company
# ...                                     ...                            ...
# 2386                         CoCoNut Porter           Maui Brewing Company
# 2387                          Big Swell IPA           Maui Brewing Company
# 2388              Urban Wilderness Pale Ale  Sleeping Lady Brewing Company
# 2389             Very Noddy Lager (Current)       Buckbean Brewing Company
# 2390            Tule Duck Red Ale (Current)       Buckbean Brewing Company
# 2391  Original Orange Blossom Ale (Current)       Buckbean Brewing Company
# 2392            Black Noddy Lager (Current)       Buckbean Brewing Company
# 2393                           Siamese twin               Uncommon Brewers
# 2394                                113 IPA        Sly Fox Brewing Company
# 2395                           Dunkel Lager        Sly Fox Brewing Company
# 2396                       Royal Weisse Ale        Sly Fox Brewing Company
# 2397                          Pikeland Pils        Sly Fox Brewing Company
# 2398                       Phoenix Pale Ale        Sly Fox Brewing Company
# 2399                          Bitter Brewer          Surly Brewing Company
# 2400                              SurlyFest          Surly Brewing Company
# 2401                          Coffee Bender          Surly Brewing Company
# 2402                                 Bender          Surly Brewing Company
# 2403                           Abrasive Ale          Surly Brewing Company
# 2404                                   Hell          Surly Brewing Company
# 2405                               CynicAle          Surly Brewing Company
# 2406                                Furious          Surly Brewing Company
# 2407                           Monk's Blood         21st Amendment Brewery
# 2408                  Brew Free! or Die IPA         21st Amendment Brewery
# 2409          Hell or High Watermelon Wheat         21st Amendment Brewery
# 2410                Ten Fidy Imperial Stout            Oskar Blues Brewery
# 2411               Mama's Little Yella Pils            Oskar Blues Brewery
# 2412                     GUBNA Imperial IPA            Oskar Blues Brewery
# 2413                               Old Chub            Oskar Blues Brewery
# 2414                      Gordon Ale (2009)            Oskar Blues Brewery
# 2415                        Dale's Pale Ale            Oskar Blues Brewery
#
#                  Location                                Style    Size   ABV  \
# 0         Minneapolis, MN                         American IPA  16 oz.   4.5
# 1         Minneapolis, MN                   Milk / Sweet Stout  16 oz.   4.9
# 2         Minneapolis, MN                    English Brown Ale  16 oz.   4.8
# 3         Minneapolis, MN                          Pumpkin Ale  16 oz.   6.0
# 4         Minneapolis, MN                      American Porter  16 oz.   6.0
# 5         Minneapolis, MN  Extra Special / Strong Bitter (ESB)  16 oz.   5.6
# 6          Louisville, KY       American Double / Imperial IPA  16 oz.   8.0
# 7          Louisville, KY                   English Barleywine  16 oz.  12.5
# 8          Louisville, KY                   Milk / Sweet Stout  16 oz.   7.7
# 9          Louisville, KY              American Pale Ale (APA)  16 oz.   4.2
# 10         Louisville, KY                      German Pilsener  16 oz.   5.0
# 11         Louisville, KY                          Pumpkin Ale  16 oz.   6.6
# 12         Louisville, KY                     Belgian Pale Ale  16 oz.   4.0
# 13         Louisville, KY                     American Pilsner  16 oz.   5.5
# 14         Louisville, KY       American Double / Imperial IPA  16 oz.   7.6
# 15         Louisville, KY               Saison / Farmhouse Ale  16 oz.   5.1
# 16         Louisville, KY                    American Wild Ale  16 oz.   6.5
# 17         Louisville, KY                         American IPA  16 oz.   6.0
# 18         Louisville, KY                    English Brown Ale  16 oz.   5.0
# 19         Framingham, MA           Keller Bier / Zwickel Bier  16 oz.   5.2
# 20         Framingham, MA                  American Pale Lager  12 oz.   4.8
# 21         Framingham, MA            American India Pale Lager  16 oz.   7.2
# 22         Framingham, MA            American India Pale Lager  12 oz.   6.7
# 23         Framingham, MA            American India Pale Lager  12 oz.   4.9
# 24          San Diego, CA       American Double / Imperial IPA  16 oz.   8.0
# 25          San Diego, CA                         American IPA  16 oz.   7.5
# 26          San Diego, CA                            Wheat Ale  16 oz.   6.0
# 27          San Diego, CA       American Double / Imperial IPA  16 oz.   8.0
# 28          San Diego, CA                            Cream Ale  16 oz.   6.3
# 29          San Diego, CA                               Kölsch  16 oz.   5.8
# ...                   ...                                  ...     ...   ...
# 2386          Lahaina, HI                      American Porter  12 oz.   5.7
# 2387          Lahaina, HI                         American IPA  12 oz.   6.2
# 2388        Anchorage, AK                     English Pale Ale  12 oz.   4.9
# 2389             Reno, NV                          Schwarzbier  16 oz.   9.9
# 2390             Reno, NV             American Amber / Red Ale  16 oz.   6.2
# 2391             Reno, NV                 Herbed / Spiced Beer  16 oz.   5.8
# 2392             Reno, NV                          Schwarzbier  16 oz.   5.2
# 2393       Santa Cruz, CA                               Dubbel  16 oz.   8.5
# 2394        Pottstown, PA                         American IPA  12 oz.   7.0
# 2395        Pottstown, PA                  Munich Dunkel Lager  12 oz.   5.3
# 2396        Pottstown, PA                           Hefeweizen  12 oz.   5.6
# 2397        Pottstown, PA                      German Pilsener  12 oz.   4.9
# 2398        Pottstown, PA              American Pale Ale (APA)  12 oz.   5.1
# 2399  Brooklyn Center, MN                       English Bitter  16 oz.   4.0
# 2400  Brooklyn Center, MN                             Rye Beer  16 oz.   5.5
# 2401  Brooklyn Center, MN                   American Brown Ale  16 oz.   5.1
# 2402  Brooklyn Center, MN                   American Brown Ale  16 oz.   5.1
# 2403  Brooklyn Center, MN       American Double / Imperial IPA  16 oz.   9.7
# 2404  Brooklyn Center, MN           Keller Bier / Zwickel Bier  16 oz.   5.1
# 2405  Brooklyn Center, MN               Saison / Farmhouse Ale  16 oz.   6.7
# 2406  Brooklyn Center, MN                         American IPA  16 oz.   6.2
# 2407    San Francisco, CA                     Belgian Dark Ale  12 oz.   8.3
# 2408    San Francisco, CA                         American IPA  12 oz.   7.0
# 2409    San Francisco, CA               Fruit / Vegetable Beer  12 oz.   4.9
# 2410         Longmont, CO               Russian Imperial Stout  12 oz.   9.9
# 2411         Longmont, CO                       Czech Pilsener  12 oz.   5.3
# 2412         Longmont, CO       American Double / Imperial IPA  12 oz.   9.9
# 2413         Longmont, CO                         Scottish Ale  12 oz.   8.0
# 2414         Longmont, CO       American Double / Imperial IPA  12 oz.   8.7
# 2415         Longmont, CO              American Pale Ale (APA)  12 oz.   6.5
#
#        IBUs
# 0      50.0
# 1      26.0
# 2      19.0
# 3      38.0
# 4      25.0
# 5      47.0
# 6      68.0
# 7      80.0
# 8      25.0
# 9      42.0
# 10     25.0
# 11     21.0
# 12     13.0
# 13     17.0
# 14     68.0
# 15     38.0
# 16      NaN
# 17     65.0
# 18     20.0
# 19     18.0
# 20     15.0
# 21     80.0
# 22     65.0
# 23     45.0
# 24    100.0
# 25     85.0
# 26     24.0
# 27    100.0
# 28     30.0
# 29     28.0
# ...     ...
# 2386   30.0
# 2387   65.0
# 2388    NaN
# 2389    NaN
# 2390   42.0
# 2391   35.0
# 2392   40.0
# 2393    NaN
# 2394  113.0
# 2395   21.0
# 2396   11.0
# 2397   44.0
# 2398   40.0
# 2399   37.0
# 2400   34.0
# 2401   45.0
# 2402   45.0
# 2403  120.0
# 2404   20.0
# 2405   33.0
# 2406   99.0
# 2407   35.0
# 2408   65.0
# 2409   17.0
# 2410   98.0
# 2411   35.0
# 2412  100.0
# 2413   35.0
# 2414   85.0
# 2415   65.0
#
# [2416 rows x 7 columns]

# %%
df.groupby(by='Location').Brewery.value_counts().head()
# Out:
# Location            Brewery
# Abingdon, VA        Wolf Hills Brewing Company          1
# Abita Springs, LA   Abita Brewing Company               3
# Ada, MI             Sietsema Orchards and Cider Mill    1
# Afton, VA           Blue Mountain Brewery               4
# Airway Heights, WA  Orlison Brewing Company             5
# Name: Brewery, dtype: int64

# %% [markdown]
# ## List all of the beer from Brooklyn, NY

# %%
df[df.Location == 'Brooklyn, NY'].Beer
# Out:
# 115                              4Beans
# 210                              Jammer
# 246                             Abigale
# 404                       Nomader Weiss
# 421                                 Rad
# 439                        Molotov Lite
# 588                             Bengali
# 713                       Sensi Harvest
# 969                              Hi-Res
# 987               KelSo Nut Brown Lager
# 1057                      Global Warmer
# 1074                 Autumnation (2013)
# 1093               KelSo India Pale Ale
# 1267                          The Crisp
# 1268                       Sweet Action
# 1269                      Righteous Ale
# 1270                      Bengali Tiger
# 1305                      KelSo Pilsner
# 1365    Hipster Ale (Two Roads Brewing)
# 1366                        Bikini Beer
# 1373                East India Pale Ale
# 1624                             3Beans
# 1836                         Brownstone
# 1857                Brooklyn Summer Ale
# 1962    Hipster Ale (Westbrook Brewing)
# 1970                             Apollo
# 1971                          Harbinger
# 1972                              Resin
# 2027                East India Pale Ale
# 2062                             Diesel
# 2074       Autumnation (2011-12) (2011)
# 2140                   The Crisp (2011)
# 2141                Sweet Action (2011)
# 2142               Righteous Ale (2011)
# 2143               Bengali Tiger (2011)
# 2219         Brooklyn Summer Ale (2011)
# 2350            Brooklyn Lager (16 oz.)
# 2351            Brooklyn Lager (12 oz.)
# Name: Beer, dtype: object

# %% [markdown]
# ## What brewery in Brooklyn puts out the most cans of beer?

# %%
df[df.Location == 'Brooklyn, NY'].Brewery.value_counts().head(1)
# Out:
# Sixpoint Craft Ales    24
# Name: Brewery, dtype: int64

# %% [markdown]
# ## What are the five most popular styles of beer produced by Sixpoint?

# %%
df[df.Brewery == 'Sixpoint Craft Ales'].Style.value_counts().head(5)
# Out:
# American IPA                      4
# Baltic Porter                     2
# Cream Ale                         2
# American Double / Imperial IPA    2
# German Pilsener                   2
# Name: Style, dtype: int64

# %% [markdown]
# ## List all of the breweries in New York state.
#
# - *Tip: We want to match *part* of the `Location` column, but not all of it.*
# - *Tip: Watch out for `NaN` values! You might be close, but you'll need to pass an extra parameter to make it work without an error.*

# %%
df[df.Location.str.contains('NY.*', na=False)].Brewery.unique()
#groupby(by='Brewery')
#df[df.Other_Race.str.contains("^HISP", na=False)].Other_Race.value_counts()
#df.Other_Race.str.replace("^HISP.*", "HISPANIC")
# Out:
# array(['Sixpoint Craft Ales', 'Evil Twin Brewing', 'Chatham Brewing',
#        'Newburgh Brewing Company', 'Southampton Publick House',
#        'Montauk Brewing Company', 'Matt Brewing Company',
#        'The Bronx Brewery', 'KelSo Beer Company', 'Brooklyn Brewery',
#        'The Manhattan Brewing Company', 'Blue Point Brewing Company',
#        'Bomb Beer Company', 'Dundee Brewing Company',
#        'Upstate Brewing Company', 'Butternuts Beer and Ale'], dtype=object)

# %% [markdown]
# ### Now *count* all of the breweries in New York state

# %%
Brewery_in_NY = df[df.Location.str.contains('NY.*', na=False)].Brewery.unique()
len(Brewery_in_NY)
# Out:
# 16

# %% [markdown]
# # Measuring International Bitterness Units
#
# ## Display all of the IPAs
#
# Include American IPAs, Imperial IPAs, and anything else with "IPA in it."
#
# IPA stands for [India Pale Ale](https://www.bonappetit.com/story/ipa-beer-styles), and is probably the most popular kind of beer in the US for people who are drinking [craft beer](https://www.craftbeer.com/beer/what-is-craft-beer).

# %%
df[df.Style.str.contains('IPA', na=False)]
# Out:
#                                    Beer                          Brewery  \
# 0                          Get Together                NorthGate Brewing
# 6                        Citra Ass Down        Against the Grain Brewery
# 14                          Rico Sauvin        Against the Grain Brewery
# 17                         Pile of Face        Against the Grain Brewery
# 24                       Habitus (2014)        Mike Hess Brewing Company
# 25                                Solis        Mike Hess Brewing Company
# 27                              Habitus        Mike Hess Brewing Company
# 33                             Villager          Fort Point Beer Company
# 38                               HopArt            COAST Brewing Company
# 39                             Boy King            COAST Brewing Company
# 43                               Rumble     Great Divide Brewing Company
# 45                                Lasso     Great Divide Brewing Company
# 48                            Titan IPA     Great Divide Brewing Company
# 55                             Nordskye               Blackrocks Brewery
# 59    98 Problems (Cuz A Hop Ain't One)           Perrin Brewing Company
# 61                       Grapefruit IPA           Perrin Brewing Company
# 62                         Train Hopper      Witch's Hat Brewing Company
# 71                             Thai.p.a               Bare Hands Brewery
# 78                             The 26th             Four Fathers Brewing
# 79                           The Gadget             Four Fathers Brewing
# 86                           Galaxyfest        450 North Brewing Company
# 87                            Citrafest        450 North Brewing Company
# 89                           Gone A-Rye              Cedar Creek Brewery
# 92                   Linnaeus Mango IPA                   Brewery Vivant
# 93                        Heavy Lifting        Boulevard Brewing Company
# 96                   Grapefruit Sculpin    Ballast Point Brewing Company
# 97                          Liberty Ale           Anchor Brewing Company
# 100                                Raja            Avery Brewing Company
# 104                          Galaxy IPA                Big Muddy Brewing
# 107               Mosaic Single Hop IPA              Lost Nation Brewing
# ...                                 ...                              ...
# 2245                      11th Hour IPA        Crow Peak Brewing Company
# 2248                   Happy Camper IPA         Santa Fe Brewing Company
# 2252                        Lucky U IPA             Breckenridge Brewery
# 2257                     The Corruption          DC Brau Brewing Company
# 2261                       Stowaway IPA           Baxter Brewing Company
# 2279                       Ice Pick Ale                Silverton Brewery
# 2281                    Cornerstone IPA  Rochester Mills Brewing Company
# 2288          Black Iron India Pale Ale     Grand Canyon Brewing Company
# 2299                 Harpoon IPA (2010)                  Harpoon Brewery
# 2306               Ranger IPA (Current)      New Belgium Brewing Company
# 2313               Avery India Pale Ale            Avery Brewing Company
# 2316                       Oasis (2010)        Tallgrass Brewing Company
# 2319                      Tallgrass IPA        Tallgrass Brewing Company
# 2326                 Third Eye Pale Ale       Steamworks Brewing Company
# 2330                    Double Haul IPA     Kettle House Brewing Company
# 2337             Upslope India Pale Ale          Upslope Brewing Company
# 2341                           Epic IPA          Mammoth Brewing Company
# 2349                    Modus Hoperandi              Ska Brewing Company
# 2365                    Snapperhead IPA          Butternuts Beer and Ale
# 2369              Ballz Deep Double IPA           7 Seas Brewing Company
# 2375             Gandhi-Bot Double IPA       New England Brewing Company
# 2379              Sea Hag IPA (Current)      New England Brewing Company
# 2382                        Caldera IPA          Caldera Brewing Company
# 2387                      Big Swell IPA             Maui Brewing Company
# 2394                            113 IPA          Sly Fox Brewing Company
# 2403                       Abrasive Ale            Surly Brewing Company
# 2406                            Furious            Surly Brewing Company
# 2408              Brew Free! or Die IPA           21st Amendment Brewery
# 2412                 GUBNA Imperial IPA              Oskar Blues Brewery
# 2414                  Gordon Ale (2009)              Oskar Blues Brewery
#
#                  Location                           Style    Size  ABV   IBUs
# 0         Minneapolis, MN                    American IPA  16 oz.  4.5   50.0
# 6          Louisville, KY  American Double / Imperial IPA  16 oz.  8.0   68.0
# 14         Louisville, KY  American Double / Imperial IPA  16 oz.  7.6   68.0
# 17         Louisville, KY                    American IPA  16 oz.  6.0   65.0
# 24          San Diego, CA  American Double / Imperial IPA  16 oz.  8.0  100.0
# 25          San Diego, CA                    American IPA  16 oz.  7.5   85.0
# 27          San Diego, CA  American Double / Imperial IPA  16 oz.  8.0  100.0
# 33      San Francisco, CA                    American IPA  12 oz.  6.3   42.0
# 38         Charleston, SC                    American IPA  16 oz.  7.7    NaN
# 39         Charleston, SC  American Double / Imperial IPA  16 oz.  9.7    NaN
# 43             Denver, CO                    American IPA  12 oz.  7.1    NaN
# 45             Denver, CO                    American IPA  12 oz.  5.0    NaN
# 48             Denver, CO                    American IPA  12 oz.  7.1    NaN
# 55          Marquette, MI                    American IPA  12 oz.  4.8   47.0
# 59      Comstock Park, MI                    American IPA  12 oz.  6.5   65.0
# 61      Comstock Park, MI                    American IPA  12 oz.  5.0   35.0
# 62         South Lyon, MI                    American IPA  12 oz.  5.8   72.0
# 71            Granger, IN                    American IPA  16 oz.  7.0   46.0
# 78         Valparaiso, IN                    American IPA  16 oz.  6.0    NaN
# 79         Valparaiso, IN                    American IPA  16 oz.  6.4   90.0
# 86           Columbus, IN                    American IPA  16 oz.  6.5    NaN
# 87           Columbus, IN                    American IPA  16 oz.  5.0   45.0
# 89       Seven Points, TX  American Double / Imperial IPA  16 oz.  8.5   90.0
# 92       Grand Rapids, MI                    American IPA  16 oz.  6.0    NaN
# 93        Kansas City, MO                    American IPA  12 oz.  6.2   80.0
# 96          San Diego, CA                    American IPA  12 oz.  7.0    NaN
# 97      San Francisco, CA                    American IPA   12 oz  5.9    NaN
# 100           Boulder, CO  American Double / Imperial IPA  12 oz.  8.0    NaN
# 104       Murphysboro, IL                    American IPA  16 oz.  7.5   60.0
# 107    East Fairfield, VT                    American IPA  16 oz.  5.5    NaN
# ...                   ...                             ...     ...  ...    ...
# 2245        Spearfish, SD                    American IPA  12 oz.  6.0    NaN
# 2248         Santa Fe, NM                    American IPA  12 oz.  6.6    NaN
# 2252           Denver, CO                    American IPA  12 oz.  6.2   68.0
# 2257       Washington, DC                    American IPA  12 oz.  6.5   80.0
# 2261         Lewiston, ME                    American IPA  12 oz.  6.9   69.0
# 2279        Silverton, CO                    American IPA  12 oz.  6.8    NaN
# 2281        Rochester, MI                    American IPA  16 oz.  7.0    NaN
# 2288         Williams, AZ                    American IPA  12 oz.  NaN    NaN
# 2299           Boston, MA                    American IPA  12 oz.  5.9   42.0
# 2306     Fort Collins, CO                    American IPA  12 oz.  6.5   70.0
# 2313          Boulder, CO                    American IPA  12 oz.  6.3   69.0
# 2316        Manhattan, KS  American Double / Imperial IPA  16 oz.  7.2   93.0
# 2319        Manhattan, KS                    American IPA  16 oz.  6.3   60.0
# 2326          Durango, CO                    American IPA  12 oz.  6.5   65.0
# 2330         Missoula, MT                    American IPA  16 oz.  6.5   65.0
# 2337          Boulder, CO                    American IPA  12 oz.  7.2    NaN
# 2341    Mammoth Lakes, CA                    American IPA  12 oz.  6.5    NaN
# 2349          Durango, CO                    American IPA  12 oz.  6.8   65.0
# 2365    Garrattsville, NY                    American IPA  12 oz.  6.8    NaN
# 2369       Gig Harbor, WA  American Double / Imperial IPA  16 oz.  8.4   82.0
# 2375       Woodbridge, CT  American Double / Imperial IPA  16 oz.  8.8   85.0
# 2379       Woodbridge, CT                    American IPA  12 oz.  6.2    NaN
# 2382          Ashland, OR                    American IPA  12 oz.  6.1   94.0
# 2387          Lahaina, HI                    American IPA  12 oz.  6.2   65.0
# 2394        Pottstown, PA                    American IPA  12 oz.  7.0  113.0
# 2403  Brooklyn Center, MN  American Double / Imperial IPA  16 oz.  9.7  120.0
# 2406  Brooklyn Center, MN                    American IPA  16 oz.  6.2   99.0
# 2408    San Francisco, CA                    American IPA  12 oz.  7.0   65.0
# 2412         Longmont, CO  American Double / Imperial IPA  12 oz.  9.9  100.0
# 2414         Longmont, CO  American Double / Imperial IPA  12 oz.  8.7   85.0
#
# [571 rows x 7 columns]

# %% [markdown]
# IPAs are usually pretty hoppy and bitter. IBU stands for [International Bitterness Unit](http://www.thebrewenthusiast.com/ibus/), and while a lot of places like to brag about having the most bitter beer (it's an American thing!), IBUs don't necessary *mean anything*.
#
# Let's look at how different beers have different IBU measurements.

# %% [markdown]
# ## Try to get the average IBU measurement across all beers

# %%
df.IBUs.mean()
#groupby(by='Beer')
# Out:
# 42.71316725978647

# %% [markdown]
# ### Oh no, it doesn't work!
#
# It looks like some of those values *aren't numbers*. There are two ways to fix this:
#
# 1. Do the `.replace` and `np.nan` thing we did in class. Then convert the column to a number. This is boring.
# 2. When you're reading in your csv, there [is an option called `na_values`](http://pandas.pydata.org/pandas-docs/version/0.23/generated/pandas.read_csv.html). You can give it a list of **numbers or strings to count as `NaN`**. It's a lot easier than doing the `np.nan` thing, although you'll need to go add it up top and run all of your cells again.
#
# - *Tip: Make sure you're giving `na_values` a LIST, not just a string*
#
# ### Now try to get the average IBUs again

# %% [markdown]
# ## Draw the distribution of IBU measurements, but with *twenty* bins instead of the default of 10
#
# - *Tip: Every time I ask for a distribution, I'm looking for a histogram*
# - *Tip: Use the `?` to get all of the options for building a histogram*
# - *Tip: Make sure your `matplotlib` thing is set up right!*

# %%
df.IBUs.hist(bins = 20)

# %% [markdown]
# ## Hm, Interesting distribution. List all of the beers with IBUs above the 75th percentile
#
# - *Tip: There's a single that gives you the 25/50/75th percentile*
# - *Tip: You can just manually type the number when you list those beers*

# %%
df.IBUs.describe()
beers_above_75 = df[df.IBUs > 64].Beer.unique()
print (beers_above_75)
# Out:
# ['Citra Ass Down' 'London Balling' 'Rico Sauvin' 'Pile of Face'
#  'Excess IPL' 'Hoponius Union' 'Habitus (2014)' 'Solis' 'Habitus'
#  'Yeti Imperial Stout' "98 Problems (Cuz A Hop Ain't One)" 'Train Hopper'
#  'Csar' 'Saucy Intruder' 'The Gadget' 'Gone A-Rye' 'Heavy Lifting'
#  'Jah Mon' 'Flying Mouse 4' 'Soul Doubt' 'Bimini Twist' 'Long Leaf'
#  'Double Duckpin' 'Hop A-Peel' 'Wobble' 'Hopkick Dropkick' 'Union Jack'
#  'India Pale Ale' 'Self Starter' 'Nugget Nectar' 'Mission IPA'
#  'Bay of Bengal Double IPA (2014)' 'Newport Storm IPA' 'Clean Shave IPA'
#  'Big Star White IPA' 'Firestarter India Pale Ale' 'Back Bay IPA'
#  '4000 Footer IPA' 'Unchained #18 Hop Silo' 'Harness the Winter'
#  'Rule G IPA' 'Yellow Wolf Imperial IPA' 'Third Eye Enlightened Pale Ale'
#  'The Green Room' '2014 IPA Cicada Series' 'Sinister Minister Black IPA'
#  'O’Malley’s IPA' 'Perpetual Darkness' 'Watershed IPA' 'Hoodoo Voodoo IPA'
#  'Hopportunity Knocks IPA' 'Mothman Black IPA' 'Homefront IPA'
#  'The Power of Zeus' 'Salamander Slam' 'Torpedo' 'Ranger IPA'
#  'Dark Voyage Black IPA (2013)' 'Scarecrow' "Lil' Helper" 'Hopworks IPA'
#  'Worthy IPA' 'Abominable Winter Ale' 'Tsunami IPA' 'Mound Builder IPA'
#  'Dream Crusher Double IPA' 'City of the Sun' '3:33 Black IPA'
#  'Booming Rollers' 'Aurora' 'More Cowbell' 'Brutus' '1916 Shore Shiver'
#  'Arcus IPA' 'Epitome' 'Hop Stalker Fresh Hop IPA' '8 Barrel'
#  'Dead-Eye DIPA' 'Count Hopula (Vault Series)' 'Dankosaurus'
#  'Might As Well IPL' "Captain's Daughter" 'Infamous IPA' 'Tropicalia'
#  'Vertex IPA' 'Operation Homefront' 'Wandering Pelican' 'Giant DIPA'
#  'Fistful Of Hops Red' 'Fistful of Hops Orange' 'Fistful Of Hops Blue'
#  'Fistful of Hops Green' 'Sky-Five' '077XX' 'Almanac IPA' 'Missile IPA'
#  'Second Fiddle' 'Let It Ride IPA' 'Bent Hop Golden IPA' 'Groupe G'
#  'Hill 88 Double IPA' 'Hoperation Overload' 'Hop Freak' 'El Chingon IPA'
#  'Saint Archer IPA' 'BLAKKR' 'Supergoose IPA' 'IPA & a Half' 'Truth'
#  'American India Red Ale' 'Squatters Hop Rising Double IPA'
#  'Quarter Mile Double IPA' 'Hoptopus Double IPA' "Filthy Hoppin' IPA"
#  '2020 IPA' 'Golden Ratio IPA' 'Hemlock Double IPA' 'Mississippi Fire Ant'
#  'Red Cockaded Ale' 'Hop Nosh IPA' 'Big Sky IPA' 'Wolf Among Weeds IPA'
#  'Be Hoppy IPA' 'Hi-Res' 'Irregardless IPA'
#  'Squatters Hop Rising Double IPA (2014)' 'The Great Return'
#  'Troopers Alley IPA' 'Madra Allta' 'Chaotic Double IPA' 'Manzanita IPA'
#  'King Street IPA' 'Sobek & Set' 'Evo IPA' 'Lucky Day IPA'
#  'Terrace Hill Double IPA' 'Catch 23' 'Better Weather IPA'
#  "Hop Drop 'N Roll IPA" 'Hop Slayer Double IPA' 'Half Cycle IPA'
#  'Initial Point India Pale Ale' 'Global Warmer' 'Good Vibes IPA'
#  'Dagger Falls IPA' 'Autumnation (2013)' '12th Round' 'RoughTail IPA'
#  'Centennial IPA' 'Double Trunk' 'Batch 69 IPA'
#  'Farmer Wirtz India Pale Ale' 'Proxima IPA' 'Monkey Fist IPA' "G'KNIGHT"
#  'Ten Fidy' 'Modus Hoperandi' 'Worthy IPA (2013)' 'Perpetual IPA'
#  'Country Boy IPA' 'Valkyrie Double IPA' 'Blazing World' 'Pilzilla'
#  'Falling Down Brown Ale' 'Shipwrecked Double IPA' 'Moirai India Pale Ale'
#  'Overlord Imperial IPA' "Dale's Pale Ale" 'F5 IPA'
#  'Wood Chipper India Pale Ale' 'Grapefruit Jungle (GFJ)'
#  'Larry Imperial IPA' "Mind's Eye PA" 'Big Eye India Pale Ale'
#  'Heal the Bay IPA' 'Laughing Dog IPA' 'Cascadian Dark Ale'
#  'Sanitas Black IPA' 'Elephant Rock IPA' 'Crank Yanker IPA'
#  'Bourbon Barrel Aged Timmie' 'Alphadelic IPA' 'Habitus IPA'
#  "Dreamin' Double IPA" "Deviant Dale's IPA" "Hop Ottin' IPA"
#  'Upslope Imperial India Pale Ale' 'Face Plant IPA' 'Bozone HopZone IPA'
#  'Nice Rack IPA' 'Old Grogham Imperial India Pale Ale' '5 Day IPA'
#  'Forest Fire Imperial Smoked Rye' 'Bad Axe Imperial IPA'
#  'Duluchan India Pale Ale' 'Dodgy Knight Imperial IPA'
#  'Indian Paintbrush IPA' 'Mutiny IPA' 'Redacted Rye IPA'
#  'Evolutionary IPA (2012)' "Old Devil's Tooth" 'Nebraska India Pale Ale'
#  'Humidor Series India Pale Ale' 'Jai Alai IPA Aged on White Oak'
#  'José Martí American Porter' 'Psychopathy'
#  'Overrated! West Coast Style IPA' 'Heady Topper' 'Descender IPA'
#  'Hop Notch IPA (2013)' 'Hop Shock IPA' 'Disconnected Red' 'Outlaw IPA'
#  'Lower De Boom' '3Beans' 'Sculpin IPA' 'Ethos IPA'
#  'Red Cockaded Ale (2013)' 'Elevation Triple India Pale Ale'
#  'Watershed IPA (2013)' 'Winterfest' 'Bitter Bitch Imperial IPA'
#  'Rude Parrot IPA' 'Des Moines IPA' 'Black IPA' 'Topcutter India Pale Ale'
#  'Twister Creek India Pale Ale' 'Deep Ellum IPA' 'Fascist Pig Ale'
#  "Frankenlou's IPA" 'Abominable Winter Ale (2012)' 'Oasis'
#  'Ex Umbris Rye Imperial Stout' 'Odyssey Imperial IPA'
#  "Dale's Pale Ale (10 Year Anniversary)" 'Hop Abomination' 'Cane and Ebel'
#  'Interurban IPA' 'PRO-AM (2012) (2012)' 'On the Wings of Armageddon'
#  "Dale's Pale Ale (2012)" 'Gordon Imperial Red (2010)' 'Gordon (2005)'
#  'Ten Fidy Imperial Stout (2008)' 'Ten Fidy Imperial Stout (2007)'
#  '21st Amendment IPA (2006)' 'Brew Free! or Die IPA (2008)'
#  'Brew Free! or Die IPA (2009)' 'Caldera IPA (2009)' 'Caldera IPA (2007)'
#  'Ace IPA' 'Double Haul IPA (2009)' 'Double Haul IPA (2006)'
#  "Dale's Pale Ale (2011)" "Dale's Pale Ale (2010)"
#  'Burning Bush Smoked IPA' 'Wolf Among Weeds IPA (2012)'
#  'Old Grogham Imperial India Pale Ale (2012)' "Dale's Pale Ale (2008)"
#  "Dale's Pale Ale (2006)" "Dale's Pale Ale (2004)"
#  "Dale's Pale Ale (2003)" "Dale's Pale Ale (2002)"
#  'Hop Slayer Double IPA (2011)' 'California Sunshine Rye IPA'
#  'Midnight Ryder' "G'KNIGHT (16 oz.)" 'Over the Rail Pale Ale'
#  'Hop A Potamus Double Dark Rye Pale Ale' 'Rodeo Clown Double IPA'
#  'Elevated IPA' 'Hopworks IPA (2012)' 'Isis' 'Hoppy Boy' 'Monkeynaut IPA'
#  'Ryeteous Rye IPA (2012)' 'Resin' 'Independence Pass Ale'
#  'HGH (Home Grown Hops): Part Duh' 'Big Sky IPA (2012)' 'Westbrook IPA'
#  'Tocobaga Red Ale' 'Eclipse Black IPA' 'Jai Alai IPA'
#  'Old Elephant Foot IPA' 'Big Cock IPA' 'Grapefruit Jungle (GFJ) (2011)'
#  'Diesel' 'Evolutionary IPA (2011)' 'Alphadelic IPA (2011)'
#  'Missouri Mule India Pale Ale' 'Hop Box Imperial IPA'
#  'Hopadillo India Pale Ale' "Bourbon's Barrel Stout"
#  'Great Crescent Stout' "Flyin' HI.P.Hay" 'Sockeye Red IPA' 'Hop Crisis'
#  'Shiva IPA' 'Anti-Hero IPA' 'Crank Yanker IPA (2011)' "G'KNIGHT (12 oz.)"
#  'Black Adder IBA (Current)' 'Upstate I.P.W.' "Hop Ottin' IPA (2011)"
#  'WET' 'Gandhi-Bot Double IPA ' 'Vortex IPA' 'Hop Shock IPA (2010)'
#  'Snake Handler Double IPA' 'Lucky U IPA' 'The Corruption' 'Stowaway IPA'
#  'Back in Black' 'Ranger IPA (Current)' 'Avery India Pale Ale'
#  'Oasis (2010)' 'Third Eye Pale Ale' 'Double Haul IPA'
#  'Ballz Deep Double IPA' 'Caldera IPA' 'Big Swell IPA' '113 IPA'
#  'Abrasive Ale' 'Furious' 'Brew Free! or Die IPA'
#  'Ten Fidy Imperial Stout' 'GUBNA Imperial IPA' 'Gordon Ale (2009)']

# %% [markdown]
# ## List all of the beers with IBUs below the 25th percentile

# %%
df.IBUs.describe()
beers_below_25 = df[df.IBUs < 21].Beer.unique()
print (beers_below_25)
# Out:
# ["Wall's End" "Sho'nuff" 'Bloody Show' 'The Brown Note' 'House Lager'
#  'Leisure Time' 'Park' 'Westfalia' 'KSA' 'Sparkle' 'Hotbox Brown' 'Gold'
#  'Cafe Leche' 'Damascene Apricot Sour' 'Sex Panther' 'Vanilla Porter'
#  'Gose' 'Vermont Pilsner' 'Ginger Peach Saison' 'Weissenheimer'
#  'Passion Fruit Prussia' 'Send Help' 'Daft Funk' 'Bat Outta Helles'
#  'Rye Wit' 'Yo Soy Un Berliner' "Farmer's Daughter Blonde" 'Honey Rye'
#  'Honey Badger Blonde' 'Old Pro' 'Vanilla Java Porter'
#  'Saddle Bronc Brown Ale' 'Bomber Mountain Amber Ale' 'Jammer'
#  'Blackberry Wheat' 'Rhode Island Blueberry' 'Watermelon Ale'
#  'Bunker Hill Blueberry Ale' 'Deception' 'P-Town Pilsner'
#  'Nonstop Hef Hop' 'Laka Laka Pineapple' 'Blood Orange Honey'
#  'Mr. Blue Sky' 'Weisse Versa (2012)' '18th Anniversary Gose'
#  'Point Special (Current)' 'Point Special' 'Morning Wood Wheat (Current)'
#  'Hunny Do Wheat' 'Gansett Light' 'Shotgun Betty' 'Knotty Blonde Ale'
#  "PUNK'N" 'Sunbru Kölsch' 'River House' 'Summer Brew'
#  'Suzy B Dirty Blonde Ale' 'Rad' 'Lobo Lito' 'American Lager'
#  'American Amber' 'American Light' 'Lake House' "Ermal's" 'Honey Kolsch'
#  'Copperhead Amber' 'Twisted X' 'Sol Drifter' '312 Urban Wheat Ale'
#  'Couch Select Lager' 'Double D Blonde' 'Lost Meridian Wit' 'Joey Wheat'
#  'Onyx Black Ale' 'Robert Earl Keen Honey Pils' "Summer's Wit"
#  'Point Special (2013)' 'Point Special (2012)' 'Broken Bridge'
#  'Point Special Lager' 'What the Butler Saw' 'Laughing Dog Cream Ale'
#  'Aprè Shred' 'Blood Orange Wit' 'Hop Up Offa That Brett (2014)'
#  'Boathouse Blonde' 'Noche Dulce' 'Weize Guy' 'UFO Gingerland' 'Skylight'
#  'Pub Ale' "Here Gose Nothin'" 'Ale Cider' 'The Great Pumpcan'
#  'Cherry Ale' 'LuckenBock' 'FMB 101' 'Upland Wheat Ale'
#  'Monkey Chased the Weasel' 'SunSpot Golden Ale' 'Beach Blonde'
#  'Alaskan Amber' 'Black Market Hefeweizen' 'Gutch English Style Mild Ale'
#  'Whitecap Wit' 'Seiche Scottish Ale' 'Local Buzz'
#  'Saint Archer White Ale' 'Porch Rocker' 'LIFT' '#9' 'The Tradition'
#  'Hot Date Ale' 'Hijack' 'Stone Fort Brown Ale' 'When Helles Freezes Over'
#  'Bronx Summer Pale Ale' 'A Slice of Hefen' '805' 'Wick For Brains'
#  'Schweet Ale' 'KelSo Nut Brown Lager' 'King Street Hefeweizen' 'Chai Ale'
#  'Banner American Rye' 'Pumpkin Beast' 'Chickawawa Lemonale'
#  'Sly Fox Christmas Ale 2013' 'Fat Tire Amber Ale' 'Four Peaks Peach Ale'
#  'Lahaina Town Brown' 'Sweet Yamma Jamma Ale' 'Starr Pils' 'Agave Wheat'
#  'Barney Flats Oatmeal Stout' 'Shark Bait' 'Golden Road Hefeweizen'
#  'Summer Paradise' 'Oval Beach Blonde Ale' 'Wolverine Premium Lager'
#  'Hideout Helles' 'Dead Eye Dunkel' 'Parcae Belgian Style Pale Ale'
#  'Norns Roggenbier' 'Laimas Kölsch Style Ale' "Stone's Throw IPA"
#  'Weiss Trash Culture' 'Kölsch 151' 'Tybee Island Blonde' 'Horny Monk'
#  'Two-One Niner' 'Old Forge Pumpkin Ale' 'Sanitas Saison Ale'
#  'Double D Blonde (2013)' 'Beaver Logger' 'Half Full Bright Ale'
#  'Point Oktoberfest' 'Schuylkill Punch' '541 American Lager'
#  'Summer Solstice' 'UFO Pumpkin' 'Float Trip Ale'
#  'Greenbelt Farmhouse Ale' 'Hardywood Cream Ale' 'Boont Amber Ale'
#  'Big Rod Coconut Ale' 'Wild Wolf Wee Heavy Scottish Style Ale'
#  'Steel Rail Extra Pale Ale' 'Westbrook Gose' 'Estival Cream Stout'
#  'Dog Days Lager' 'Samuel Adams Octoberfest' 'Longboard Island Lager'
#  'El Hefe Speaks' 'Dos Pistolas' 'Cotton Mouth' 'Wild Night'
#  'Love Street Summer Seasonal (2014)' 'Point Nude Beach Summer Wheat'
#  "SUM'R" 'Twisted Helles Summer Lager' 'Bomber Mountain Amber Ale (2013)'
#  'Saddle Bronc Brown Ale (2013)' 'Wagon Box Wheat Beer'
#  'Wild Plum Farmhouse Ale' 'Peninsula Brewers Reserve (PBR)'
#  'Hazy Day Belgian-Style Wit' "Mo's Gose" 'Lumberyard Pilsner'
#  'Woolybugger Wheat' 'EOS Hefeweizen' 'Brunette Nut Brown Ale'
#  'Samuel Adams Summer Ale' 'Helles Golden Lager' 'Elder Betty'
#  'Sweet As Pacific Ale' 'Epicenter Amber Ale' 'SanTan HefeWeizen'
#  'Barn Burner Saison' 'Vanilla Bean Buffalo Sweat'
#  "The Hole in Hadrian's Wall" 'Honey Wheat' 'The Lawn Ranger'
#  'Country Pale Ale' 'Orange Wheat' 'Hangar 24 Helles Lager'
#  'Tallgrass Pub Ale' 'Get Up Offa That Brown' 'Booyah Farmhouse Ale'
#  'Sly Fox Christmas Ale 2012 (2012)' 'Northern Lights Amber Ale'
#  'Polar Pale Ale' 'Pumpkan' 'Wheat the People' 'Apricot Blonde'
#  'Lawnmower Lager' 'Dry Dock Hefeweizen' 'Widespread Wit'
#  'Bombshell Blonde' 'Sex Panther (2014)' 'Black Walnut Wheat'
#  'Boont Amber Ale (2010)' 'Hell or High Watermelon Wheat (2009)'
#  '21st Amendment Watermelon Wheat Beer (2006)' 'Choc Beer (2003)'
#  'Mr. Pineapple' 'Blueberry Blonde Ale'
#  'Point Nude Beach Summer Wheat (2011)' 'Buffalo Sweat'
#  'Cold Smoke Scotch Ale (2007)' 'Summer Solstice Cerveza Crema (2009)'
#  'Fat Tire Amber Ale (2011)' "Hilliard's Blonde"
#  'Devils Tramping Ground Tripel' 'Lava Lake Wit'
#  'Halcyon Unfiltered Wheat' 'Blue Point Summer Ale' 'Three Kings Ale'
#  'Full Boar Scotch Ale' 'Cherry Ale (1)' 'Apollo' 'Blacktop Blonde'
#  'Wachusett Blueberry Ale' 'UFO White' 'Rosa Hibiscus Ale'
#  'Schlafly Hefeweizen' 'Snowshoe White Ale' '312 Urban Wheat Ale (2012)'
#  'White Thai' 'Blackbeary Wheat' 'Barney Flats Oatmeal Stout (2012)'
#  'Jon Boat Coastal Ale' 'Golden Road Hefeweizen (2012)' 'La Perouse White'
#  'Florida Cracker Belgian Wit' 'Dirty Blonde Ale' 'Tin Roof Blonde Ale'
#  "Atwater's Lager" 'Winter Solstice' 'McKinney Eddy Amber Ale'
#  'SoDo Brown Ale' 'Purple Haze' 'Abita Amber' 'Double D Blonde (2011)'
#  'Great Crescent Belgian Style Wit' 'Joseph James American Lager'
#  'Top Rope Mexican-style Craft Lager' 'Weisse Versa'
#  'Dundee Summer Wheat Beer' 'Mustang Golden Ale' 'Washita Wheat'
#  'Bottom Up Belgian Wit' 'Snake River Lager'
#  'Black Star Double Hopped Golden Lager ' 'Pyramid Hefeweizen (2011)'
#  'Wild Onion Summer Wit' 'SummerBright Ale' 'Whitsun' 'Mexican Logger'
#  'Festie' 'Narragansett Fest Lager' 'Mana Wheat'
#  'SanTan HefeWeizen (2010)' 'Flaming Damsel Lager (2010)'
#  'Point Nude Beach Summer Wheat (2010)' 'Point Amber Classic'
#  "O'Fallon Wheach" 'Epicenter Amber Ale (2010)' 'White Rascal'
#  'Ellie’s Brown Ale' 'Köld Lager (2010)' 'Buffalo Sweat (2010)'
#  'Colorado Kölsch' 'Cold Smoke Scotch Ale' 'Avalanche Ale'
#  'Haywire Hefeweizen (2010)' 'Boont Amber Ale (2011)'
#  'Summer Solstice (2011)' 'Fat Tire Amber Ale (2008)' 'Sunlight Cream Ale'
#  'Schlafly Summer Lager' 'Bikini Blonde Lager' 'Royal Weisse Ale' 'Hell'
#  'Hell or High Watermelon Wheat']

# %% [markdown]
# ## List the median IBUs of each type of beer. Graph it.
#
# Put the highest at the top, and the missing ones at the bottom.
#
# - Tip: Look at the options for `sort_values` to figure out the `NaN` thing. The `?` probably won't help you here.

# %%
df.groupby(by='Style').IBUs.median().sort_values(ascending=False)
# Out:
# Style
# American Barleywine                    96.0
# Russian Imperial Stout                 94.0
# American Double / Imperial IPA         91.0
# American Double / Imperial Pilsner     85.0
# American Black Ale                     73.0
# Belgian Strong Dark Ale                72.0
# American Strong Ale                    70.0
# American IPA                           69.0
# English Stout                          66.0
# American India Pale Lager              65.0
# Belgian IPA                            61.0
# English Barleywine                     60.0
# Rye Beer                               57.0
# Baltic Porter                          52.0
# English Strong Ale                     52.0
# American Double / Imperial Stout       51.0
# English India Pale Ale (IPA)           47.0
# American White IPA                     45.0
# American Pale Ale (APA)                44.0
# Extra Special / Strong Bitter (ESB)    41.0
# California Common / Steam Beer         41.0
# Old Ale                                40.0
# American Stout                         40.0
# Altbier                                36.5
# Foreign / Export Stout                 36.0
# Smoked Beer                            35.0
# Belgian Dark Ale                       35.0
# German Pilsener                        35.0
# Irish Dry Stout                        34.0
# Czech Pilsener                         33.0
#                                        ...
# Munich Dunkel Lager                    21.0
# English Brown Ale                      20.5
# American Blonde Ale                    20.0
# American Pale Wheat Ale                20.0
# Roggenbier                             20.0
# Pumpkin Ale                            20.0
# Keller Bier / Zwickel Bier             20.0
# Cream Ale                              20.0
# American Pale Lager                    18.5
# Munich Helles Lager                    18.0
# English Pale Mild Ale                  16.0
# Dunkelweizen                           16.0
# Other                                  16.0
# Witbier                                15.5
# Fruit / Vegetable Beer                 15.5
# Herbed / Spiced Beer                   15.0
# Hefeweizen                             15.0
# Light Lager                            12.0
# Gose                                   10.0
# American Adjunct Lager                  9.0
# Berliner Weissbier                      8.0
# American Malt Liquor                    NaN
# Braggot                                 NaN
# Cider                                   NaN
# Flanders Red Ale                        NaN
# Kristalweizen                           NaN
# Low Alcohol Beer                        NaN
# Mead                                    NaN
# Rauchbier                               NaN
# Shandy                                  NaN
# Name: IBUs, Length: 99, dtype: float64

# %%
df.groupby(by='Style').IBUs.median().sort_values(ascending=False).hist(bins=30)

# %% [markdown]
# ## Hmmmm, it looks like they are generally different styles. What are the most common 5 styles of high-IBU beer vs. low-IBU beer?
#
# - *Tip: You'll want to think about it in three pieces - filtering to only find the specific beers beers, then finding out what the most common styles are, then getting the top 5.*
# - *Tip: You CANNOT do this in one command. It's going to be one command for the high and one for the low.*
# - *Tip: "High IBU" means higher than 75th percentile, "Low IBU" is under 25th percentile*

# %%
#beers_below_25
#beers_above_75
df[df.IBUs > 64].Style.value_counts().head(5)
# Out:
# American IPA                      195
# American Double / Imperial IPA     72
# American Pale Ale (APA)            18
# American Black Ale                 15
# American Strong Ale                 9
# Name: Style, dtype: int64

# %%
df[df.IBUs < 21].Style.value_counts().head(5)
# Out:
# American Pale Wheat Ale    43
# American Blonde Ale        36
# Fruit / Vegetable Beer     28
# Hefeweizen                 21
# Witbier                    20
# Name: Style, dtype: int64

# %% [markdown]
# ## Get the average IBU of "Witbier", "Hefeweizen" and "American Pale Wheat Ale" styles
#
# I'm counting these as wheat beers. If you see any other wheat beer categories, feel free to include them. I want ONE measurement and ONE graph, not three separate ones. And 20 to 30 bins in the histogram, please.
#
# - *Tip: I hope that `isin` is in your toolbox*

# %%
df[df.Style.isin(['Witbier', 'Hefeweizen', 'American Pale Wheat Ale'])].IBUs.mean()
# Out:
# 18.982142857142858

# %% [markdown]
# ## Draw a histogram of the IBUs of those beers

# %%
df[df.Style.isin(['Witbier', 'Hefeweizen', 'American Pale Wheat Ale'])].IBUs.hist(bins=25)

# %% [markdown]
# ## Get the average IBU of any style with "IPA" in it (also draw a histogram)

# %%
df[df.Style.str.contains('IPA', na=False)].IBUs.mean()
# Out:
# 71.94897959183673

# %%
df[df.Style.str.contains('IPA', na=False)].IBUs.hist(bins=25)

# %% [markdown]
# ## Plot those two histograms on top of one another
#
# To plot two plots on top of one another, you do two steps.
#
# 1. First, you make a plot using `plot` or `hist`, and you save it into a variable called `ax`.
# 2. You draw your second graph using `plot` or `hist`, and send `ax=ax` to it as a parameter.
#
# It would look something like this:
#
# ```python
# ax = df.plot(....)
# df.plot(ax=ax, ....)
# ```
#
# (...except totally different)

# %%
ax = df[df.Style.isin(['Witbier', 'Hefeweizen', 'American Pale Wheat Ale'])].IBUs.hist(bins=30)
df[df.Style.str.contains('IPA', na=False)].IBUs.hist(ax=ax, bins=30, alpha=0.5)

# %% [markdown]
# ## Compare the ABV of wheat beers vs. IPAs : their IBUs were really different, but how about their alcohol percentage?
#
# Wheat beers might include witbier, hefeweizen, American Pale Wheat Ale, and anything else you think is wheaty. IPAs probably have "IPA" in their name.

# %%
ax = df[df.Style.isin(['Witbier', 'Hefeweizen', 'American Pale Wheat Ale'])].ABV.hist(bins=30)
df[df.Style.str.contains('IPA', na=False)].ABV.hist(ax=ax, bins=30, alpha=0.5)

# %% [markdown]
# ## Good work!
#
# If you made it this far you deserve a drink.
